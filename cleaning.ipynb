# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.read_excel("EF2022.xlsx",)
# Out:
#       type                                               name  \
# 0     Chat    JIC: Monash & W. Michigan Uni (Australia, Ma...
# 1     Chat    JIC: Monash & W. Michigan Uni (Australia, Ma...
# 2     Chat    JIC: Monash & W. Michigan Uni (Australia, Ma...
# 3     Chat    JIC: Monash & W. Michigan Uni (Australia, Ma...
# 4     Chat    JIC: Monash & W. Michigan Uni (Australia, Ma...
# ...    ...                                                ...
# 9328  Chat                                              UNPAR
# 9329  Chat                                              UNPAR
# 9330  Chat                                              UNPAR
# 9331  Chat                                              UNPAR
# 9332  Chat                                              UNPAR
#
#                                   name.1  \
# 0                    Hilario Arles Hogan
# 1                     William Wirohusodo
# 2     Bonifacius Galih Pramuditho Rennes
# 3           Christian Yudistira Hermawan
# ...
